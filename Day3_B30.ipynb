# %%
name='Ravi'
print(name)
# Out:
# Ravi

# %%
type(name)
# Out:
# str

# %%
fullname='ravi mishra'
print(fullname)
# Out:
# ravi mishra

# %%
print(fullname.title())
# Out:
# Ravi Mishra

# %%
print(fullname.upper())
# Out:
# RAVI MISHRA

# %%
print(fullname.lower())
# Out:
# ravi mishra

# %%
firstname='ravi'
lastname='mishra'

# %%
fullname= f"{firstname} {lastname}"
print(fullname)
# Out:
# ravi mishra

# %%
print(fullname.title())
# Out:
# Ravi Mishra

# %%
print(fullname.upper())
# Out:
# RAVI MISHRA

# %%
print(fullname.lower())
# Out:
# ravi mishra

# %%
x = f"keep up the good work, {fullname}"
print(x)
# Out:
# keep up the good work, ravi mishra

# %%
x = f"keep up the good work, {fullname.title()}"
print(x)
# Out:
# keep up the good work, Ravi Mishra

# %%
x = f"keep up the good work, {fullname.upper()}"
print(x)
# Out:
# keep up the good work, RAVI MISHRA

# %%
x = f"keep up the good work, {fullname.lower()}"
print(x)
# Out:
# keep up the good work, ravi mishra

# %%
print('Fruits Name:Apple Apricots Avocado Banana Blackberries')
# Out:
# Fruits Name:Apple Apricots Avocado Banana Blackberries

# %%
print('Fruits Name:\nApple\nApricots\nAvocado\nBanana\nBlackberries')
# Out:
# Fruits Name:
# Apple
# Apricots
# Avocado
# Banana
# Blackberries
