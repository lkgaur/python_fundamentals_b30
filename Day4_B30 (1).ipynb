# %%
print('Fruits Name:\nApple\nApricots\nAvocado\nBanana\nBlackberries')
# Out:
# Fruits Name:
# Apple
# Apricots
# Avocado
# Banana
# Blackberries

# %%
print('Fruits Name:\n\tApple\n\tApricots\n\tAvocado\n\tBanana\n\tBlackberries')
# Out:
# Fruits Name:
# 	Apple
# 	Apricots
# 	Avocado
# 	Banana
# 	Blackberries

# %%
a = 'Apple'
print(a)
# Out:
# Apple

# %%
b= '     Apple'
print(b)
# Out:
#      Apple

# %%
c= 'Apple     '
print(c)
# Out:
# Apple

# %%
b.lstrip()
# Out:
# 'Apple'

# %%
c.rstrip()
# Out:
# 'Apple'

# %%
a = "    paython_basics       "
print(a)
# Out:
#     paython_basics

# %%
a = "    paython_basics       "
a.strip()
# Out:
# 'paython_basics'

# %%
4+5
# Out:
# 9

# %%
6-4
# Out:
# 2

# %%
4*4
# Out:
# 16

# %%
6/2
# Out:
# 3.0

# %%
a = 5
b = 3
c = a+b
print(c)
# Out:
# 8

# %%
type(c)
# Out:
# int

# %%
4.0 + 5.5
# Out:
# 9.5

# %%
a= 4.0
b= 5.5
c=a+b
print(c)
# Out:
# 9.5

# %%
type(c)
# Out:
# float
