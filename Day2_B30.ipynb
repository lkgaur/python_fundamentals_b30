# %%
a=10
b=5

# %%
a+b
# Out:
# 15

# %%
firstname="Rohan"
print(firstname)
# Out:
# Rohan

# %%
first_name="Ravi"
print(first_name)
# Out:
# Ravi

# %%
name1="Anugya"
print(name1)
# Out:
# Anugya

# %%
name1='Rohan'
print(name1)
# Out:
# Rohan

# %%
name2="Ravi"
print(name2)
# Out:
# Ravi

# %%
name3="""Anugya"""
print(name3)
# Out:
# Anugya
